# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cols = ['area', 'perimeter', 'compactness', 'length', 'width', 'asymmetry', 'groove', 'class']
df = pd.read_csv('seeds_dataset.txt', names=cols, delim_whitespace=True)
df.head()
# Out:
# /tmp/ipykernel_114583/2630678978.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv('seeds_dataset.txt', names=cols, delim_whitespace=True)
#     area  perimeter  compactness  length  width  asymmetry  groove  class
# 0  15.26      14.84       0.8710   5.763  3.312      2.221   5.220      1
# 1  14.88      14.57       0.8811   5.554  3.333      1.018   4.956      1
# 2  14.29      14.09       0.9050   5.291  3.337      2.699   4.825      1
# 3  13.84      13.94       0.8955   5.324  3.379      2.259   4.805      1
# 4  16.14      14.99       0.9034   5.658  3.562      1.355   5.175      1

# %%
for i in range(len(cols)-1):
    for j in range(i+1, len(cols)-1):
        x_label = cols[i]
        y_label = cols[j]
        sns.scatterplot(x=x_label, y=y_label, data=df, hue='class')
        plt.show()

# %% [markdown]
# # Clustering

# %%
from sklearn.cluster import KMeans

# %%
x='compactness'
y='asymmetry'
X = df[[x, y]].values

# %%
kmeans = KMeans(n_clusters=3).fit(X)
clusters = kmeans.labels_

# %%
cluster_df = pd.DataFrame(np.hstack((X, clusters.reshape(-1,1))), columns = [x, y, 'class'])

# %%
sns.scatterplot(x=x, y=y, data=cluster_df, hue='class')
plt.plot()
# Out:
# []

# %%
sns.scatterplot(x=x, y=y, data=df, hue='class')
plt.plot()
# Out:
# []

# %% [markdown]
# # Higher Dimensions

# %%
X = df[cols[:-1]].values

# %%
kmeans = KMeans(n_clusters = 3).fit(X)
cluster_df = pd.DataFrame(np.hstack((X, kmeans.labels_.reshape(-1,1))), columns=df.columns)

# %%
# KMeans classes
sns.scatterplot(x=x, y=y, data=cluster_df, hue='class')
plt.plot()
# Out:
# []

# %%
# Original classes
sns.scatterplot(x=x, y=y, data=df, hue='class')
plt.plot()
# Out:
# []

# %% [markdown]
# # Principal Component Analysis

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
transformed_x = pca.fit_transform(X)

# %%
transformed_x[:5]
# Out:
# array([[ 0.66344838, -1.41732098],
#        [ 0.31566651, -2.68922915],
#        [-0.6604993 , -1.13150635],
#        [-1.0552759 , -1.62119002],
#        [ 1.61999921, -2.18338442]])

# %% [markdown]
# plt.scatter(transformed_x[:,0], transformed_x[:,1])
# plt.show()

# %%
kmeans_pca_df = pd.DataFrame(np.hstack((transformed_x, kmeans.labels_.reshape(-1,1))), columns =['pca1', 'pca2', 'class'])

# %%
truth_pca_df = pd.DataFrame(np.hstack((transformed_x, df['class'].values.reshape(-1,1))), columns =['pca1', 'pca2', 'class'])

# %%
sns.scatterplot(x='pca1', y='pca2', data=kmeans_pca_df,  hue='class')
plt.plot()
# Out:
# []

# %%
sns.scatterplot(x='pca1', y='pca2', data=truth_pca_df,  hue='class')
plt.plot()
# Out:
# []
